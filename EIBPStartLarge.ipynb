# %% [markdown]
# # Prepare Code to be Run on EIBP Nodes

# %% [markdown]
# ## INITIALIZATION: Input Required Information
#
# | Variable | Use |
# | --- | --- |
# | SLICE_NAME    | Name of the slice you wish to work on. |
# | CONFIG_FILE | Configuration file for the nodes. |
# | CODE_DIR | Directory of the EIBP source code. |

# %%
SLICE_NAME = "Eibp_PTPLARGE132"
CONFIG_FILE = "config_large_13node.txt"
CODE_DIR = "/home/fabric/work/EIBP/SRC_Code"

# %% [markdown]
# ## Access the Slice
#
# The orchestrator class is initalized, which also means the slice and its nodes are now accessable as well.

# %%
from FabUtils import FabOrchestrator

try:
    manager = FabOrchestrator(SLICE_NAME)
    
except Exception as e:
    print(f"Exception: {e}")
# Out:
# Slice name: Eibp_PTPLARGE132
# Slice and nodes were acquired successfully.

# %% [markdown]
# ## KILL tmux session MNLR (if required)

# %%
stopCmd = "tmux kill-session -t MNLR"
manager.executeCommandsParallel(stopCmd, prefixList="A")
manager.executeCommandsParallel(stopCmd, prefixList="D")
manager.executeCommandsParallel(stopCmd, prefixList="C")
# Out:
# Starting command on node A1
# Command to execute: tmux kill-session -t MNLR
# Starting command on node A2
# Command to execute: tmux kill-session -t MNLR
# Starting command on node A3
# Command to execute: tmux kill-session -t MNLR
# Starting command on node A4
# Command to execute: tmux kill-session -t MNLR
# Starting command on node A5
# Command to execute: tmux kill-session -t MNLR
#
# ==== A1 RESULTS ====
# stdout:
#
# stderr:
# no server running on /tmp/tmux-1000/default
#
#
# ==== A2 RESULTS ====
# stdout:
#
# stderr:
# error connecting to /tmp//tmux-1000/default (No such file or directory)
#
#
# ==== A3 RESULTS ====
# stdout:
#
# stderr:
# no server running on /tmp/tmux-1000/default
#
#
# ==== A4 RESULTS ====
# stdout:
#
# stderr:
# no server running on /tmp/tmux-1000/default
#
#
# ==== A5 RESULTS ====
# stdout:
#
# stderr:
# no server running on /tmp/tmux-1000/default
#
# Starting command on node D1
# Command to execute: tmux kill-session -t MNLR
# Starting command on node D2
# Command to execute: tmux kill-session -t MNLR
# Starting command on node D3
# Command to execute: tmux kill-session -t MNLR
# Starting command on node D4
# Command to execute: tmux kill-session -t MNLR
# Starting command on node D5
# Command to execute: tmux kill-session -t MNLR
#
# ==== D1 RESULTS ====
# stdout:
#
# stderr:
# no server running on /tmp/tmux-1000/default
#
#
# ==== D2 RESULTS ====
# stdout:
#
# stderr:
# error connecting to /tmp//tmux-1000/default (No such file or directory)
#
#
# ==== D3 RESULTS ====
# stdout:
#
# stderr:
# error connecting to /tmp//tmux-1000/default (No such file or directory)
#
#
# ==== D4 RESULTS ====
# stdout:
#
# stderr:
# error connecting to /tmp//tmux-1000/default (No such file or directory)
#
#
# ==== D5 RESULTS ====
# stdout:
#
# stderr:
# error connecting to /tmp//tmux-1000/default (No such file or directory)
#
# Starting command on node C1
# Command to execute: tmux kill-session -t MNLR
# Starting command on node C2
# Command to execute: tmux kill-session -t MNLR
# Starting command on node C3
# Command to execute: tmux kill-session -t MNLR
#
# ==== C1 RESULTS ====
# stdout:
#
# stderr:
# error connecting to /tmp//tmux-1000/default (No such file or directory)
#
#
# ==== C2 RESULTS ====
# stdout:
#
# stderr:
# error connecting to /tmp//tmux-1000/default (No such file or directory)
#
#
# ==== C3 RESULTS ====
# stdout:
#
# stderr:
# error connecting to /tmp//tmux-1000/default (No such file or directory)

# %% [markdown]
# ## Delete the Log from a Prior Test (if required)
#
# This code is executing the command to remove log files with names starting with "EIBP_" for three nodes (prefixes): "c," "d," and "a," using a manager's function called "executeCommandsParallel."

# %%
rmLogCmd = "rm EIBP_*.log"
manager.executeCommandsParallel(rmLogCmd, prefixList="C,D,A")
# Out:
# Starting command on node C1
# Command to execute: rm EIBP_*.log
# Starting command on node C2
# Command to execute: rm EIBP_*.log
# Starting command on node C3
# Command to execute: rm EIBP_*.log
# Starting command on node D1
# Command to execute: rm EIBP_*.log
# Starting command on node D2
# Command to execute: rm EIBP_*.log
# Starting command on node D3
# Command to execute: rm EIBP_*.log
# Starting command on node D4
# Command to execute: rm EIBP_*.log
# Starting command on node D5
# Command to execute: rm EIBP_*.log
# Starting command on node A1
# Command to execute: rm EIBP_*.log
# Starting command on node A2
# Command to execute: rm EIBP_*.log
# Starting command on node A3
# Command to execute: rm EIBP_*.log
# Starting command on node A4
# Command to execute: rm EIBP_*.log
# Starting command on node A5
# Command to execute: rm EIBP_*.log
#
# ==== C1 RESULTS ====
# stdout:
#
# stderr:
# rm: cannot remove 'EIBP_*.log': No such file or directory
#
#
# ==== C2 RESULTS ====
# stdout:
#
# stderr:
# rm: cannot remove 'EIBP_*.log': No such file or directory
#
#
# ==== C3 RESULTS ====
# stdout:
#
# stderr:
# rm: cannot remove 'EIBP_*.log': No such file or directory
#
#
# ==== D1 RESULTS ====
# stdout:
#
# stderr:
# rm: cannot remove 'EIBP_*.log': No such file or directory
#
#
# ==== D2 RESULTS ====
# stdout:
#
# stderr:
# rm: cannot remove 'EIBP_*.log': No such file or directory
#
#
# ==== D3 RESULTS ====
# stdout:
#
# stderr:
# rm: cannot remove 'EIBP_*.log': No such file or directory
#
#
# ==== D4 RESULTS ====
# stdout:
#
# stderr:
# rm: cannot remove 'EIBP_*.log': No such file or directory
#
#
# ==== D5 RESULTS ====
# stdout:
#
# stderr:
# rm: cannot remove 'EIBP_*.log': No such file or directory
#
#
# ==== A1 RESULTS ====
# stdout:
#
# stderr:
# rm: cannot remove 'EIBP_*.log': No such file or directory
#
#
# ==== A2 RESULTS ====
# stdout:
#
# stderr:
# rm: cannot remove 'EIBP_*.log': No such file or directory
#
#
# ==== A3 RESULTS ====
# stdout:
#
# stderr:
# rm: cannot remove 'EIBP_*.log': No such file or directory
#
#
# ==== A4 RESULTS ====
# stdout:
#
# stderr:
# rm: cannot remove 'EIBP_*.log': No such file or directory
#
#
# ==== A5 RESULTS ====
# stdout:
#
# stderr:
# rm: cannot remove 'EIBP_*.log': No such file or directory

# %% [markdown]
# ## Delete MNLR_Code in the slice (if required)
#
# This code is executing the "rm -rf MNLR_Code/" command to recursively delete the directory "MNLR_Code" in for three prefixes: "c," "d," and "a," using a manager's function called "executeCommandsParallel.

# %%
deleteexec= "rm -rf SRC_Code/"
manager.executeCommandsParallel(deleteexec, prefixList="C,D,A")
# Out:
# Starting command on node C1
# Command to execute: rm -rf SRC_Code/
# Starting command on node C2
# Command to execute: rm -rf SRC_Code/
# Starting command on node C3
# Command to execute: rm -rf SRC_Code/
# Starting command on node D1
# Command to execute: rm -rf SRC_Code/
# Starting command on node D2
# Command to execute: rm -rf SRC_Code/
# Starting command on node D3
# Command to execute: rm -rf SRC_Code/
# Starting command on node D4
# Command to execute: rm -rf SRC_Code/
# Starting command on node D5
# Command to execute: rm -rf SRC_Code/
# Starting command on node A1
# Command to execute: rm -rf SRC_Code/
# Starting command on node A2
# Command to execute: rm -rf SRC_Code/
# Starting command on node A3
# Command to execute: rm -rf SRC_Code/
# Starting command on node A4
# Command to execute: rm -rf SRC_Code/
# Starting command on node A5
# Command to execute: rm -rf SRC_Code/
#
# ==== C1 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== C2 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== C3 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== D1 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== D2 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== D3 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== D4 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== D5 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== A1 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== A2 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== A3 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== A4 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== A5 RESULTS ====
# stdout:
#
# stderr:

# %% [markdown]
# ## Upload the Source Code
#
# This code is uploading the directory specified by the variable "CODE_DIR" to multiple destinations( all the nodes), identified by the prefixes "c," "d," and "a," using a manager's function called "uploadDirectoryParallel."

# %%
manager.uploadDirectoryParallel(CODE_DIR, prefixList="C,D,A")
# Out:
# Directory to upload: /home/fabric/work/EIBP/SRC_Code
# Placed in: /home/rocky
# Starting upload on node C1
# Starting upload on node C2
# Starting upload on node C3
# Starting upload on node D1
# Starting upload on node D2
# Starting upload on node D3
# Starting upload on node D4
# Starting upload on node D5
# Starting upload on node A1
# Starting upload on node A2
# Starting upload on node A3
# Starting upload on node A4
# Starting upload on node A5
# Waiting for result from node C1
# Output: success
# Waiting for result from node C2
# Output: success
# Waiting for result from node C3
# Output: success
# Waiting for result from node D1
# Output: success
# Waiting for result from node D2
# Output: success
# Waiting for result from node D3
# Output: success
# Waiting for result from node D4
# Output: success
# Waiting for result from node D5
# Output: success
# Waiting for result from node A1
# Output: success
# Waiting for result from node A2
# Output: success
# Waiting for result from node A3
# Output: success
# Waiting for result from node A4
# Output: success
# Waiting for result from node A5
# Output: success

# %% [markdown]
# ## Compile the Code
#
# This code compiles C source files in the "MNLR_Code/" directory into an executable named "MNLR" using GCC, with debugging and error handling flags in all nodes.

# %%
compileCmd = "cd SRC_Code/; gcc -g -Wfatal-errors -o MNLR *.c -lm -w"
manager.executeCommandsParallel(compileCmd, prefixList="C,D,A")
# Out:
# Starting command on node C1
# Command to execute: cd SRC_Code/; gcc -g -Wfatal-errors -o MNLR *.c -lm -w
# Starting command on node C2
# Command to execute: cd SRC_Code/; gcc -g -Wfatal-errors -o MNLR *.c -lm -w
# Starting command on node C3
# Command to execute: cd SRC_Code/; gcc -g -Wfatal-errors -o MNLR *.c -lm -w
# Starting command on node D1
# Command to execute: cd SRC_Code/; gcc -g -Wfatal-errors -o MNLR *.c -lm -w
# Starting command on node D2
# Command to execute: cd SRC_Code/; gcc -g -Wfatal-errors -o MNLR *.c -lm -w
# Starting command on node D3
# Command to execute: cd SRC_Code/; gcc -g -Wfatal-errors -o MNLR *.c -lm -w
# Starting command on node D4
# Command to execute: cd SRC_Code/; gcc -g -Wfatal-errors -o MNLR *.c -lm -w
# Starting command on node D5
# Command to execute: cd SRC_Code/; gcc -g -Wfatal-errors -o MNLR *.c -lm -w
# Starting command on node A1
# Command to execute: cd SRC_Code/; gcc -g -Wfatal-errors -o MNLR *.c -lm -w
# Starting command on node A2
# Command to execute: cd SRC_Code/; gcc -g -Wfatal-errors -o MNLR *.c -lm -w
# Starting command on node A3
# Command to execute: cd SRC_Code/; gcc -g -Wfatal-errors -o MNLR *.c -lm -w
# Starting command on node A4
# Command to execute: cd SRC_Code/; gcc -g -Wfatal-errors -o MNLR *.c -lm -w
# Starting command on node A5
# Command to execute: cd SRC_Code/; gcc -g -Wfatal-errors -o MNLR *.c -lm -w
#
# ==== C1 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== C2 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== C3 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== D1 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== D2 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== D3 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== D4 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== D5 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== A1 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== A2 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== A3 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== A4 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== A5 RESULTS ====
# stdout:
#
# stderr:

# %% [markdown]
# ## Reading command file and running MNLR code on each node using tmux
#
# This code reads a configuration file ('config.txt') with node names and associated commands, storing them in a dictionary. It then uses this data to create and execute new tmux sessions for each node with the specified command using a manager's function.

# %%
import time

# Open the .txt file for reading
with open('config_large.txt', 'r') as file:
    # Initialize an empty dictionary to store the configuration data
    config_data = {}
    
    # Loop through each line in the file
    for line in file:
        # Split the line by comma to separate the node name and command
        parts = line.strip().split(',')
        
        # Check if there are two parts (node name and command)
        if len(parts) == 2:
            node_name, command = parts
            config_data[node_name] = command

# Now you have a dictionary with node names as keys and commands as values
# You can access the data like this:
for node_name, command in config_data.items():
    print(f"Node: {node_name}, Command: {command}")
    startCmd = f"tmux new-session -d -s MNLR 'cd ~/SRC_Code; {command}'"
    if node_name in ("A1"):
        print("Waiting 30 seconds")
        time.sleep(30)
    print(startCmd)
    manager.executeCommandsParallel(startCmd, prefixList=node_name)
    time.sleep(5)
# Out:
# Node: C1, Command: sudo ./MNLR -T 1 -L 1.1 -N 1
# tmux new-session -d -s MNLR 'cd ~/SRC_Code; sudo ./MNLR -T 1 -L 1.1 -N 1'
# Starting command on node C1
# Command to execute: tmux new-session -d -s MNLR 'cd ~/SRC_Code; sudo ./MNLR -T 1 -L 1.1 -N 1'
#
# ==== C1 RESULTS ====
# stdout:
#
# stderr:
#
# Node: C2, Command: sudo ./MNLR -T 1 -L 1.2 -N 1
# tmux new-session -d -s MNLR 'cd ~/SRC_Code; sudo ./MNLR -T 1 -L 1.2 -N 1'
# Starting command on node C2
# Command to execute: tmux new-session -d -s MNLR 'cd ~/SRC_Code; sudo ./MNLR -T 1 -L 1.2 -N 1'
#
# ==== C2 RESULTS ====
# stdout:
#
# stderr:
#
# Node: D1, Command: sudo ./MNLR -T 2 -N 1
# tmux new-session -d -s MNLR 'cd ~/SRC_Code; sudo ./MNLR -T 2 -N 1'
# Starting command on node D1
# Command to execute: tmux new-session -d -s MNLR 'cd ~/SRC_Code; sudo ./MNLR -T 2 -N 1'
#
# ==== D1 RESULTS ====
# stdout:
#
# stderr:
#
# Node: D2, Command: sudo ./MNLR -T 2 -N 1
# tmux new-session -d -s MNLR 'cd ~/SRC_Code; sudo ./MNLR -T 2 -N 1'
# Starting command on node D2
# Command to execute: tmux new-session -d -s MNLR 'cd ~/SRC_Code; sudo ./MNLR -T 2 -N 1'
#
# ==== D2 RESULTS ====
# stdout:
#
# stderr:
#
# Node: D3, Command: sudo ./MNLR -T 2 -N 1
# tmux new-session -d -s MNLR 'cd ~/SRC_Code; sudo ./MNLR -T 2 -N 1'
# Starting command on node D3
# Command to execute: tmux new-session -d -s MNLR 'cd ~/SRC_Code; sudo ./MNLR -T 2 -N 1'
#
# ==== D3 RESULTS ====
# stdout:
#
# stderr:
#
# Node: A1, Command: sudo ./MNLR -T 3 -N 0 192.168.1.254 24 eth3
# Waiting 30 seconds
# tmux new-session -d -s MNLR 'cd ~/SRC_Code; sudo ./MNLR -T 3 -N 0 192.168.1.254 24 eth3'
# Starting command on node A1
# Command to execute: tmux new-session -d -s MNLR 'cd ~/SRC_Code; sudo ./MNLR -T 3 -N 0 192.168.1.254 24 eth3'
#
# ==== A1 RESULTS ====
# stdout:
#
# stderr:
#
# Node: A2, Command: sudo ./MNLR -T 3 -N 0 192.168.2.254 24 eth1
# tmux new-session -d -s MNLR 'cd ~/SRC_Code; sudo ./MNLR -T 3 -N 0 192.168.2.254 24 eth1'
# Starting command on node A2
# Command to execute: tmux new-session -d -s MNLR 'cd ~/SRC_Code; sudo ./MNLR -T 3 -N 0 192.168.2.254 24 eth1'
#
# ==== A2 RESULTS ====
# stdout:
#
# stderr:
#
# Node: A3, Command: sudo ./MNLR -T 3 -N 0 192.168.3.254 24 eth3
# tmux new-session -d -s MNLR 'cd ~/SRC_Code; sudo ./MNLR -T 3 -N 0 192.168.3.254 24 eth3'
# Starting command on node A3
# Command to execute: tmux new-session -d -s MNLR 'cd ~/SRC_Code; sudo ./MNLR -T 3 -N 0 192.168.3.254 24 eth3'
#
# ==== A3 RESULTS ====
# stdout:
#
# stderr:

# %% [markdown]
# ## WAIT FOR a MINUTE

# %%
time.sleep(75)

# %% [markdown]
# ## KILL tmux session MNLR

# %%
stopCmd = "tmux kill-session -t MNLR"
manager.executeCommandsParallel(stopCmd, prefixList="A")
manager.executeCommandsParallel(stopCmd, prefixList="D")
manager.executeCommandsParallel(stopCmd, prefixList="C")
# Out:
# Starting command on node A1
# Command to execute: tmux kill-session -t MNLR
# Starting command on node A2
# Command to execute: tmux kill-session -t MNLR
# Starting command on node A3
# Command to execute: tmux kill-session -t MNLR
#
# ==== A1 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== A2 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== A3 RESULTS ====
# stdout:
#
# stderr:
#
# Starting command on node D1
# Command to execute: tmux kill-session -t MNLR
# Starting command on node D2
# Command to execute: tmux kill-session -t MNLR
# Starting command on node D3
# Command to execute: tmux kill-session -t MNLR
#
# ==== D1 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== D2 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== D3 RESULTS ====
# stdout:
#
# stderr:
#
# Starting command on node C1
# Command to execute: tmux kill-session -t MNLR
# Starting command on node C2
# Command to execute: tmux kill-session -t MNLR
#
# ==== C1 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== C2 RESULTS ====
# stdout:
#
# stderr:

# %% [markdown]
# ## WAIT FEW MINUTES

# %%
time.sleep(60)

# %% [markdown]
# ## Collect Log Results
#
# This code creates a directory for log files if it doesn't exist and then downloads log files named in the format "EIBP_{name}.log" from multiple destinations with prefixes "c," "d," and "a" into the specified log directory.It also adds the node name to the downloaded log files' names.
#
# Now that the nodes have logged updates to their respective log files, they need to be downloaded to be analyzed.

# %%
import os

LOG_DIR_PATH = "logs_large"
LOG_NAME = "EIBP_{name}.log"
logPath = os.path.join(LOG_DIR_PATH, LOG_NAME)

# If the logs directory does not already exist, create it
if not os.path.exists(LOG_DIR_PATH):
    os.makedirs(LOG_DIR_PATH)

manager.downloadFilesParallel(logPath, LOG_NAME, prefixList="C,D,A", addNodeName=True)
# Out:
# Starting download on node C1
# File to download: EIBP_C1.log
# Location of download: logs_large/EIBP_C1.log
# Starting download on node C2
# File to download: EIBP_C2.log
# Location of download: logs_large/EIBP_C2.log
# Starting download on node C3
# File to download: EIBP_C3.log
# Location of download: logs_large/EIBP_C3.log
# Starting download on node D1
# File to download: EIBP_D1.log
# Location of download: logs_large/EIBP_D1.log
# Starting download on node D2
# File to download: EIBP_D2.log
# Location of download: logs_large/EIBP_D2.log
# Starting download on node D3
# File to download: EIBP_D3.log
# Location of download: logs_large/EIBP_D3.log
# Starting download on node D4
# File to download: EIBP_D4.log
# Location of download: logs_large/EIBP_D4.log
# Starting download on node D5
# File to download: EIBP_D5.log
# Location of download: logs_large/EIBP_D5.log
# Starting download on node A1
# File to download: EIBP_A1.log
# Location of download: logs_large/EIBP_A1.log
# Starting download on node A2
# File to download: EIBP_A2.log
# Location of download: logs_large/EIBP_A2.log
# Starting download on node A3
# File to download: EIBP_A3.log
# Location of download: logs_large/EIBP_A3.log
# Starting download on node A4
# File to download: EIBP_A4.log
# Location of download: logs_large/EIBP_A4.log
# Starting download on node A5
# File to download: EIBP_A5.log
# Location of download: logs_large/EIBP_A5.log
# Waiting for result from node C1
# Exception: [Errno 2] No such file
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[9], line 11
#       8 if not os.path.exists(LOG_DIR_PATH):
#       9     os.makedirs(LOG_DIR_PATH)
# ---> 11 manager.downloadFilesParallel(logPath, LOG_NAME, prefixList="C,D,A", addNodeName=True)
#
# File ~/work/EIBP/Scripts/local_books/Small_Topology/FabUtils.py:215, in FabOrchestrator.downloadFilesParallel(self, localLocation, remoteLocation, prefixList, excludedList, addNodeName)
#     212     except Exception as e:
#     213         print(f"Exception: {e}")
# --> 215     print(f"Output: {output}")
#     217 return
#
# UnboundLocalError: cannot access local variable 'output' where it is not associated with a value

# %% [markdown]
# ## Delete the Log from a Prior Test (if required)
#
# This code is executing the command to remove log files with names starting with "EIBP_" for three nodes (prefixes): "c," "d," and "a," using a manager's function called "executeCommandsParallel."

# %%
rmLogCmd = "rm EIBP_*.log"
manager.executeCommandsParallel(rmLogCmd, prefixList="C,D,A")
# Out:
# Starting command on node C1
# Command to execute: rm EIBP_*.log
# Starting command on node C2
# Command to execute: rm EIBP_*.log
# Starting command on node C3
# Command to execute: rm EIBP_*.log
# Starting command on node D1
# Command to execute: rm EIBP_*.log
# Starting command on node D2
# Command to execute: rm EIBP_*.log
# Starting command on node D3
# Command to execute: rm EIBP_*.log
# Starting command on node D4
# Command to execute: rm EIBP_*.log
# Starting command on node D5
# Command to execute: rm EIBP_*.log
# Starting command on node A1
# Command to execute: rm EIBP_*.log
# Starting command on node A2
# Command to execute: rm EIBP_*.log
# Starting command on node A3
# Command to execute: rm EIBP_*.log
# Starting command on node A4
# Command to execute: rm EIBP_*.log
# Starting command on node A5
# Command to execute: rm EIBP_*.log
#
# ==== C1 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== C2 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== C3 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== D1 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== D2 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== D3 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== D4 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== D5 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== A1 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== A2 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== A3 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== A4 RESULTS ====
# stdout:
#
# stderr:
#
#
# ==== A5 RESULTS ====
# stdout:
#
# stderr:
